# %% [markdown]
# <center><a href="https://www.nvidia.com/en-us/training/"><img src="https://dli-lms.s3.amazonaws.com/assets/general/DLI_Header_White.png" width="400" height="186" /></a></center>

# %% [markdown]
# # 3b. OCR Pipelines
#
# Today, many large language model (LLM) systems can derive insights from various media such as news articles and academic papers. Both of these sources contain multimodal data such as text, figures, and tables. This tutorial provides a step-by-step guide showing how to isolate different modalities from multimodal PDF documents. The process of analyzing text in images is called Optical Character Recognition, or OCR. Let's create a multimodal pipeline with OCR and other PDF data extraction techniques to be used in a pipeline for LLM models. When an LLM retrieves information from such a pipeline, it's called retrieval augmented generation, or RAG.
#
# ![DLI_extract.png](data:image/png;base64,...)
#
# In this tutorial, we will be using the open-source [unstructured](https://github.com/Unstructured-IO/unstructured) library for pre-processing images, tables and text from PDF documents.
#
#
# #### Learning Objectives
#
# The goals of this notebook are to:
# * Explore Text Chunking
# * Explore Table Extraction
# * Explore Images/Plots Extraction
# * Explore Identifying page elements with YOLOX-L
# * Create an End-to-End Multimodal Data Extraction Pipeline
#
# Let's load some libraries to get started.

# %%
import os
import getpass
import ipyplot
import requests
import base64
import cv2
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image as IPyImage
from IPython.display import IFrame

from pathlib import Path

IMG_DIR = "ocr/images"

# %% [markdown]
# ## 3.1 Setup
#
# In this example, we will use the NVIDIA GB200 NVL72 white paper. It contains tables, plots, images and text description. Run the cell below to take a look.

# %%
filename = "data/grace-blackwell-datasheet.pdf"
IFrame(filename, width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="data/grace-blackwell-datasheet.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Let's segment the PDF document using unstructured's `partition_pdf` function and extract the text. Optical Character Recognition (OCR) will be used on images when the text is not already available in the PDF format. This library relies on the [Tesseract OCR](https://github.com/tesseract-ocr/tesseract) tool.

# %%
from unstructured.partition.pdf import partition_pdf
from unstructured.documents.elements import Text, Image, Table, CompositeElement

# %% [markdown]
# We can use `partition_pdf` directly on the pdf file to extract useful elements. Each element is a section of text.

# %%
elements = partition_pdf(filename)
print("Retrieved elements: ", len(elements))
# Out:
# Retrieved elements:  154

# %% [markdown]
# To get a sense of what these elements look like, let's print each element and its corresponding page number.

# %%
for el in elements:
    if isinstance(el, Text):
        print("page ", el.metadata.page_number)
        print(el.text.strip())
# Out:
# page  1
# Datasheet
# page  1
# NVIDIA GB200 NVL72 Powering the new era of computing.
# page  1
# Unlocking Real-Time Trillion-Parameter Models
# page  1
# NVIDIA GB200 NVL72 connects 36 Grace CPUs and 72 Blackwell GPUs in an NVIDIA®
# page  1
# NVLink®-connected, liquid-cooled, rack-scale design. Acting as a single, massive GPU, it
# page  1
# delivers 30X faster real-time trillion-parameter large language model (LLM) inference.
# page  1
# The GB200 Grace Blackwell Superchip is a key component of the NVIDIA GB200 NVL72, connecting two high-performance NVIDIA Blackwell GPUs and an NVIDIA Grace CPU with the NVLink-C2C interconnect.
# page  1
# Real-Time LLM Inference
# page  1
# Output Tokens per Second per GPU4080
# page  1
# 116GB200 NVL7202060100120
# page  1
# HGX H1003.530X
# page  1
# GB200 NVL72 introduces cutting-edge capabilities and a second-generation
# page  1
# Transformer Engine, which enables FP4 AI and, when coupled with fifth-generation
# page  1
# NVLink, delivers 30X faster real-time inference performance for trillion-parameter
# page  1
# language models. This advancement is made possible with a new generation of Tensor
# page  1
# Cores, which introduce new microscaling formats, giving high accuracy and greater
# page  1
# throughput. Additionally, the GB200 NVL72 uses NVLink and liquid cooling to create a
# page  1
# single, massive 72-GPU rack that can overcome communication bottlenecks.
# page  1
# GPT-MoE-1.8T Real-Time Throughput
# page  1
# LLM inference and energy efficiency: token-to-token latency (TTL) = 50 milliseconds (ms) real time, first token latency (FTL) = 5s, 32,768 input/1,024 output, NVIDIA HGX™ H100 scaled over InfiniBand (IB) versus GB200 NVL72.
# page  1
# Key Features
# page  1
# > 36 NVIDIA Grace™ CPUs
# page  1
# > 72 NVIDIA Blackwell GPUs
# page  1
# > Up to 17 terabytes (TB) of
# page  1
# LPDDR5X memory with error-
# page  1
# correction code (ECC)
# page  1
# > Supports up to 13.5TB of HBM3e
# page  1
# > Up to 30.5TB of fast-access
# page  1
# memory
# page  1
# > NVLINK Domain: 130 terabytes
# page  1
# per second (TB/s) of low-latency
# page  1
# GPU communication
# page  1
# NVIDIA GB200 NVL72 | Datasheet | 1
# page  2
# 1XHGX H100
# page  2
# 02X4X5X
# page  2
# Speedup Over H1001X3X
# page  2
# 4XGB200 NVL72
# page  2
# Massive-Scale Training
# page  2
# GB200 NVL72 includes a faster second-generation Transformer Engine featuring
# page  2
# FP8 precision, which enables a remarkable 4X faster training for large language
# page  2
# models at scale. This breakthrough is complemented by the fifth-generation
# page  2
# NVLink, which provides 1.8 terabytes per second (TB/s) of GPU-to-GPU interconnect, InfiniBand networking, and NVIDIA Magnum IO™ software.
# page  2
# GPT-MoE-1.8T Model Training Speedup
# page  2
# 05152530
# page  2
# H100 GPU1X
# page  2
# 25XGB200 NVL72
# page  2
# Relative Energy Efficiency1020
# page  2
# 1.8T mixture of experts (MoE) 4,096x HGX H100 scaled over IB vs. 456x GB200 NVL72 scaled over IB. Cluster size: 32,768.
# page  2
# Energy-Efficient Infrastructure
# page  2
# Liquid-cooled GB200 NVL72 racks reduce a data center’s carbon footprint and
# page  2
# energy consumption. Liquid cooling increases compute density, reduces the
# page  2
# amount of floor space used, and facilitates high-bandwidth, low-latency GPU communication with large NVLink domain architectures. Compared to NVIDIA H100 air-cooled infrastructure, GB200 delivers 25X more performance at the same power
# page  2
# while reducing water consumption.
# page  2
# Energy Efficiency
# page  2
# Energy savings for 65 racks eight-way HGX H100 air-cooled versus one rack GB200 NLV72 liquid-cooled with equivalent performance on GPT-MoE-1.8T real- time inference throughput.
# page  2
# NVIDIA GB200 NVL72 | Datasheet | 2
# page  3
# 0104080100
# page  3
# x865
# page  3
# Queries per Minutes206050903070
# page  3
# 90GB200 NVL72
# page  3
# 15H100 GPU
# page  3
# 18X
# page  3
# Data Processing
# page  3
# Databases play critical roles in handling, processing, and analyzing large volumes
# page  3
# of data for enterprises. GB200 takes advantage of the high-bandwidth-memory performance, NVLink-C2C, and dedicated decompression engines in the NVIDIA Blackwell architecture to speed up key database queries by 18X compared to CPU, delivering a 5X better TCO.
# page  3
# Database Join Query
# page  3
# Results subject to change.
# page  3
# Full NVIDIA Platform Support
# page  3
# The NVIDIA GB200 Grace Blackwell Superchip extends the existing large and
# page  3
# diverse ecosystem of 64-bit Arm® processors. The very same containers, application
# page  3
# binaries, and operating systems that run on other Arm products run on Grace
# page  3
# Blackwell without modification—only faster. And for customers who wish to
# page  3
# leverage and build upon NVIDIA’s software expertise, the NVIDIA Grace Blackwell
# page  3
# Superchip is supported by the full NVIDIA software stack, including the NVIDIA HPC,
# page  3
# NVIDIA AI, and NVIDIA Omniverse™ platforms.
# page  3
# NVIDIA GB200 NVL72 | Datasheet | 3
# page  4
# Product Specifications1
# page  4
# The NVIDIA GB200 Grace Blackwell Superchip comes in two configurations: GB200 NVL72 and GB200 NVL2.
# page  4
# Feature
# page  4
# GB200 NVL72
# page  4
# GB200 NVL2
# page  4
# Configuration
# page  4
# 36 Grace CPUs,
# page  4
# 2 Grace CPUs,
# page  4
# 72 Blackwell GPUs
# page  4
# 2 Blackwell GPUs
# page  4
# FP4 Tensor Core2
# page  4
# 1,440 PFLOPS
# page  4
# 40 PFLOPS
# page  4
# FP8/FP6 Tensor Core2
# page  4
# 720 PFLOPS
# page  4
# 20 PFLOPS
# page  4
# INT8 Tensor Core2
# page  4
# 720 POPS
# page  4
# 20 POPS
# page  4
# FP16/BF16 Tensor Core2
# page  4
# 360 PFLOPS
# page  4
# 10 PFLOPS
# page  4
# TF32 Tensor Core2
# page  4
# 180 TFLOPS
# page  4
# 5 PFLOPS
# page  4
# FP32
# page  4
# 6,480 TFLOPS
# page  4
# 180 TFLOPS
# page  4
# FP64
# page  4
# 3,240 TFLOPS
# page  4
# 90 TFLOPS
# page  4
# FP64 Tensor Core
# page  4
# 3,240 TFLOPS
# page  4
# 90 TFLOPS
# page  4
# GPU Memory | Bandwidth
# page  4
# Up to 13.5TB
# page  4
# Up to 384GB
# page  4
# HBM3e | 576TB/s
# page  4
# HBM3e | 16TB/s
# page  4
# NVLink Bandwidth
# page  4
# 130TB/s
# page  4
# 3.6 TB/s
# page  4
# CPU Core Count
# page  4
# 2,592 Arm Neoverse
# page  4
# 144 Arm Newoverse V2 cores
# page  4
# V2 cores
# page  4
# CPU Memory | Bandwidth
# page  4
# Up to 17TB LPDDR5X | Up
# page  4
# Up to 960GB LPDDR5X | Up
# page  4
# to 18.4TB/s
# page  4
# to 1,024GB/s
# page  4
# Form Factor
# page  4
# MGX Rack
# page  4
# MGX
# page  4
# 1. Preliminary specifications. May be subject to change.
# page  4
# 2. With sparsity.
# page  4
# Ready to Get Started?
# page  4
# To learn more about the NVIDIA GB200 NVL72, visit: www.nvidia.com/en-us/data-center/grace-Blackwell-superchip
# page  4
# To download the NVIDIA Grace Blackwell architecture whitepaper, visit: resources.nvidia.com/en-us-grace-cpu/nvidia-grace-Blackwell
# page  4
# © 2024 2NVIDIA Corporation and affiliates. All rights reserved. NVIDIA, the NVIDIA logo, Grace, HGX, Magnum IO, NVLInk, and Omniverse are trademarks and/or registered trademarks of NVIDIA Corporation and affiliates in the U.S. and other countries. Other company and product names may be trademarks of the respective owners with which they are associated. 3267163. JUN24.
# page  4
# GB200 Grace Blackwell Superchip
# page  4
# 1 Grace CPU,
# page  4
# 2 Blackwell GPUs
# page  4
# 40 PFLOPS
# page  4
# 20 PFLOPS
# page  4
# 20 POPS
# page  4
# 10 PFLOPS
# page  4
# 5 PFLOPS
# page  4
# 180 TFLOPS
# page  4
# 90 TFLOPS
# page  4
# 90 TFLOPS
# page  4
# Up to 384GB
# page  4
# HBM3e | 16TB/s
# page  4
# 3.6TB/s
# page  4
# 72 Arm Neoverse V2 cores
# page  4
# Up to 480GB LPDDR5X | Up
# page  4
# to 512GB/s
# page  4
# Module

# %% [markdown]
# ## 3.2 Explore Text Chunking

# %% [markdown]
# Text chunking involves transforming the text data from the PDF into smaller chunks that can be embedded and stored for later retrieval. The library provides a naive chunking strategy based on chunk size parameters (max characters). This method is purely syntactic and can limit the performance of the RAG pipeline if the chunks are not semantically distinct enough.
#
# There is a more granular chunking strategy `by_title` where section boundaries are preserved and we can split the text into more semantically distinct chunks. Let's check the granular chunking strategy:

# %%
granular_elements = partition_pdf(
    filename,
    chunking_strategy="by_title",
    max_characters=2000,
    new_after_n_chars=1800,
    combine_text_under_n_chars=1000,
)

# %% [markdown]
# First, let's check how many text sections are detected:

# %%
# check how many text section detected
print("Retrieved granular elements: ", len(granular_elements))
# Out:
# Retrieved granular elements:  6

# %% [markdown]
# Next, let's compare the first extracted section for both methods:

# %%
# let's compare extracted section 1 for both methods
print("Naive chunking method: \t", elements[0].text.strip()[:200], end="\n\n")
print("Granular chunking method: \t", granular_elements[0].text.strip()[:200], "...")
# Out:
# Naive chunking method: 	 Datasheet
#
# Granular chunking method: 	 Datasheet
#
# NVIDIA GB200 NVL72 Powering the new era of computing.
#
# Unlocking Real-Time Trillion-Parameter Models
#
# NVIDIA GB200 NVL72 connects 36 Grace CPUs and 72 Blackwell GPUs in an NVIDIA®
#
# NVLink®- ...

# %% [markdown]
# The granular chunking method has extracted and grouped together the same sections of text from the PDF. This should help the retrieval process of our OCR pipeline.

# %% [markdown]
# ## 3.3 Explore Table Extraction
# The [unstructured](https://unstructured.io/) library uses the transformer-based object detection model [microsoft/table-transformer-structure-recognition](https://huggingface.co/microsoft/table-transformer-structure-recognition) to extract tables from PDFs.
#
# To enable this, we will need to specify `infer_table_structure` as True.
#
# <div class="alert alert-warning">Running the next cell can take about ~22s</div>

# %%
# %%time
table_text_elements = partition_pdf(
    filename, infer_table_structure=True, strategy="hi_res"
)
# Out:
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# CPU times: user 1min 31s, sys: 1.36 s, total: 1min 32s
# Wall time: 11.4 s

# %% [markdown]
# The `text_as_html` element metadata attribute allows us to directly view the elements corresponding HTML.

# %%
for el in table_text_elements:
    if type(el) == Table:
        print("Table")
        print(el.metadata.text_as_html)
        el_html = el.metadata.text_as_html
# Out:
# Table
# <table><thead><tr><th rowspan="2">Configuration</th><th>36 Grace CPUs,</th><th>2 Grace CPUs,</th><th>1 Grac e CPU,</th></tr><tr><th>72 Blackwell GPUs</th><th>2 Blackwell GPUs</th><th>2 Blackwell GPUs</th></tr></thead><tbody><tr><td>FP4 Tensor Core?</td><td>1,440 PFLOPS</td><td>40 PFLOPS</td><td>40 PFLOPS</td></tr><tr><td>FP8/FP6 Tensor Core?</td><td>720 PFLOPS</td><td>20 PFLOPS</td><td>20 PFLOPS</td></tr><tr><td>INT8 Tensor Core?</td><td>720 POPS</td><td>20 POPS</td><td>20 POPS</td></tr><tr><td>FP16/BF 16 Tensor Core?</td><td>360 PFLOPS</td><td>10 PFLOPS</td><td>10 PFLOPS</td></tr><tr><td>TF32 Tensor Core?</td><td>180 TFLOPS</td><td>5 PFLOPS</td><td>5 PFLOPS</td></tr><tr><td>FP32</td><td>6,480 TFLOPS</td><td>180 TFLOPS</td><td>180 TFLOPS</td></tr><tr><td>FP64</td><td>3,240 TFLOPS</td><td>90 TFLOPS</td><td>90 TFLOPS</td></tr><tr><td>FP64 Tensor Core</td><td>3,240 TFLOPS</td><td>90 TFLOPS</td><td>90 TFLOPS</td></tr><tr><td>GPU Memory | Bandwidth</td><td>Up to 13.5TB HBMBe | 576TB/s</td><td>Up to 384GB HBMBe | 16TB/s</td><td>Up to 384GB HBMBe | 16TB/s</td></tr><tr><td>NVLink Bandwidth</td><td>130TB/s</td><td>3.6 TB/s</td><td>3.6TB/s</td></tr><tr><td>CPU Core Count</td><td>2,592 Arm Neoverse V2 cores</td><td>144 Arm Newoverse V2 cores</td><td>72 Arm Neoverse V2 cores</td></tr><tr><td>CPU Memory | Bandwidth</td><td>Up to 17TB LPDDR5X | Up to 18.4TB/s</td><td>Up to 960GB LPDDR5X | Up to 1,024GB/s</td><td>Up to 480GB LPDDR5X | Up to 512GB/s</td></tr></tbody></table>

# %% [markdown]
# We can then convert this information into html data which can then be ingested by the [LangChain](https://python.langchain.com/docs/introduction/) framework, a popular framework used to make LLM applications.

# %%
from langchain.docstore.document import Document

table_elements = [
    Document(
        page_content=e.metadata.text_as_html,
        metadata={"filename": e.metadata.filename, "source_type": "table_html"},
    )
    for e in table_text_elements
    if type(e) == Table
]

# check first element
table_elements[0].page_content
# Out:
# '<table><thead><tr><th rowspan="2">Configuration</th><th>36 Grace CPUs,</th><th>2 Grace CPUs,</th><th>1 Grac e CPU,</th></tr><tr><th>72 Blackwell GPUs</th><th>2 Blackwell GPUs</th><th>2 Blackwell GPUs</th></tr></thead><tbody><tr><td>FP4 Tensor Core?</td><td>1,440 PFLOPS</td><td>40 PFLOPS</td><td>40 PFLOPS</td></tr><tr><td>FP8/FP6 Tensor Core?</td><td>720 PFLOPS</td><td>20 PFLOPS</td><td>20 PFLOPS</td></tr><tr><td>INT8 Tensor Core?</td><td>720 POPS</td><td>20 POPS</td><td>20 POPS</td></tr><tr><td>FP16/BF 16 Tensor Core?</td><td>360 PFLOPS</td><td>10 PFLOPS</td><td>10 PFLOPS</td></tr><tr><td>TF32 Tensor Core?</td><td>180 TFLOPS</td><td>5 PFLOPS</td><td>5 PFLOPS</td></tr><tr><td>FP32</td><td>6,480 TFLOPS</td><td>180 TFLOPS</td><td>180 TFLOPS</td></tr><tr><td>FP64</td><td>3,240 TFLOPS</td><td>90 TFLOPS</td><td>90 TFLOPS</td></tr><tr><td>FP64 Tensor Core</td><td>3,240 TFLOPS</td><td>90 TFLOPS</td><td>90 TFLOPS</td></tr><tr><td>GPU Memory | Bandwidth</td><td>Up to 13.5TB HBMBe | 576TB/s</td><td>Up to 384GB HBMBe | 16TB/s</td><td>Up to 384GB HBMBe | 16TB/s</td></tr><tr><td>NVLink Bandwidth</td><td>130TB/s</td><td>3.6 TB/s</td><td>3.6TB/s</td></tr><tr><td>CPU Core Count</td><td>2,592 Arm Neoverse V2 cores</td><td>144 Arm Newoverse V2 cores</td><td>72 Arm Neoverse V2 cores</td></tr><tr><td>CPU Memory | Bandwidth</td><td>Up to 17TB LPDDR5X | Up to 18.4TB/s</td><td>Up to 960GB LPDDR5X | Up to 1,024GB/s</td><td>Up to 480GB LPDDR5X | Up to 512GB/s</td></tr></tbody></table>'

# %% [markdown]
# Since this content is HTML, we can display it within this Jupiter notebook like we could on a web page.

# %%
# print the table as HTML
from IPython.core.display import HTML
from IPython.display import display
display(HTML(el_html))
# Out:
# <table><thead><tr><th rowspan="2">Configuration</th><th>36 Grace CPUs,</th><th>2 Grace CPUs,</th><th>1 Grac e CPU,</th></tr><tr><th>72 Blackwell GPUs</th><th>2 Blackwell GPUs</th><th>2 Blackwell GPUs</th></tr></thead><tbody><tr><td>FP4 Tensor Core?</td><td>1,440 PFLOPS</td><td>40 PFLOPS</td><td>40 PFLOPS</td></tr><tr><td>FP8/FP6 Tensor Core?</td><td>720 PFLOPS</td><td>20 PFLOPS</td><td>20 PFLOPS</td></tr><tr><td>INT8 Tensor Core?</td><td>720 POPS</td><td>20 POPS</td><td>20 POPS</td></tr><tr><td>FP16/BF 16 Tensor Core?</td><td>360 PFLOPS</td><td>10 PFLOPS</td><td>10 PFLOPS</td></tr><tr><td>TF32 Tensor Core?</td><td>180 TFLOPS</td><td>5 PFLOPS</td><td>5 PFLOPS</td></tr><tr><td>FP32</td><td>6,480 TFLOPS</td><td>180 TFLOPS</td><td>180 TFLOPS</td></tr><tr><td>FP64</td><td>3,240 TFLOPS</td><td>90 TFLOPS</td><td>90 TFLOPS</td></tr><tr><td>FP64 Tensor Core</td><td>3,240 TFLOPS</td><td>90 TFLOPS</td><td>90 TFLOPS</td></tr><tr><td>GPU Memory | Bandwidth</td><td>Up to 13.5TB HBMBe | 576TB/s</td><td>Up to 384GB HBMBe | 16TB/s</td><td>Up to 384GB HBMBe | 16TB/s</td></tr><tr><td>NVLink Bandwidth</td><td>130TB/s</td><td>3.6 TB/s</td><td>3.6TB/s</td></tr><tr><td>CPU Core Count</td><td>2,592 Arm Neoverse V2 cores</td><td>144 Arm Newoverse V2 cores</td><td>72 Arm Neoverse V2 cores</td></tr><tr><td>CPU Memory | Bandwidth</td><td>Up to 17TB LPDDR5X | Up to 18.4TB/s</td><td>Up to 960GB LPDDR5X | Up to 1,024GB/s</td><td>Up to 480GB LPDDR5X | Up to 512GB/s</td></tr></tbody></table>

# %% [markdown]
# Most of the table has been accurately extracted, but there are some missing rows. The table extraction performance could be improved using techniques such as converting the PDF to markdown format and using the markdown representation of the table for retrieval, or by extracting the table as an image, which we will look at next.
#
# ## 3.4 Explore Images/Plots Extraction
#
# To extract images from a PDF, we can set `extract_images_in_pdf=True`. The `unstructured` library uses the [YOLOX](https://arxiv.org/pdf/2107.08430v2) model to detect images. YOLOX is an anchor-free version of YOLO (You Only Look Once), a one-shot object detection model series from Megvii Technology.
#
# ```
# elements = partition(filename=filename,
#                      strategy="hi-res",
#                      hi_res_model_name="yolox")
# ```
#
# <div class="alert alert-warning">Running the next cell can take about 12s.</div>

# %%
os.environ["UNSTRUCTURED_HI_RES_MODEL_NAME"] = "yolox"

# %%
image_text_elements = partition_pdf(
    filename=filename,
    strategy="hi_res",
    hi_res_model_name="yolox",
    extract_images_in_pdf=True,
    extract_image_block_types=["Image"],
    extract_image_block_to_payload=False,
    extract_image_block_output_dir=IMG_DIR
)

# %% [markdown]
# Let's check the outputs to verify images were extracted.

# %%
images = [e.metadata.image_path for e in image_text_elements if type(e) == Image]
print("list of extracted images:\n", images)
# Out:
# list of extracted images:
#  ['ocr/images/figure-1-1.jpg', 'ocr/images/figure-1-2.jpg', 'ocr/images/figure-2-3.jpg', 'ocr/images/figure-2-4.jpg', 'ocr/images/figure-3-5.jpg', 'ocr/images/figure-4-6.jpg']

# %% [markdown]
# We can then create a function to visualize the extracted images:

# %%
def plot_images_from_folder(folder_path=None, image_files=None):
    if image_files == None:
        image_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
    if image_files:
        ipyplot.plot_images(image_files, max_images=20, img_width=200, show_url=False)
    else:
        print("No images found in the specified folder.")

# %%
plot_images_from_folder(image_files=images)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4Nzj4MSeWMm9HHcAijJDpV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4Nzj4MSeWMm9HHcAijJDpV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4Nzj4MSeWMm9HHcAijJDpV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4Nzj4MSeWMm9HHcAijJDpV:checked ~ #ipyplot-html-viewer-textarea-4Nzj4MSeWMm9HHcAijJDpV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4Nzj4MSeWMm9HHcAijJDpV:checked + #ipyplot-html-viewer-label-4Nzj4MSeWMm9HHcAijJDpV:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4Nzj4MSeWMm9HHcAijJDpV">
#         <label id="ipyplot-html-viewer-label-4Nzj4MSeWMm9HHcAijJDpV" for="ipyplot-html-viewer-toggle-4Nzj4MSeWMm9HHcAijJDpV">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4Nzj4MSeWMm9HHcAijJDpV" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-MR96GCL79P2CJqfeBSn4ui {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-MR96GCL79P2CJqfeBSn4ui">
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-EP7f6ounKfxu5axCfgBudK" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/images/figure-1-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-EP7f6ounKfxu5axCfgBudK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-8yLnV5emMRPb4V3ZoG3Wsr" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/images/figure-1-2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-8yLnV5emMRPb4V3ZoG3Wsr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-SPcngaoKyDXtdDZMrqQ7w6" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/images/figure-2-3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-SPcngaoKyDXtdDZMrqQ7w6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-ijNuYR3o7bHY9qiCKaZEgp" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/images/figure-2-4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-ijNuYR3o7bHY9qiCKaZEgp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-CUGkJj9wTAzYtiE6mH2nzm" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="ocr/images/figure-3-5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-CUGkJj9wTAzYtiE6mH2nzm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-bTVnYM6WGWSGHMTCdp2tGT" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="ocr/images/figure-4-6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-bTVnYM6WGWSGHMTCdp2tGT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-MR96GCL79P2CJqfeBSn4ui {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-MR96GCL79P2CJqfeBSn4ui">
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-EP7f6ounKfxu5axCfgBudK" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/images/figure-1-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-EP7f6ounKfxu5axCfgBudK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-8yLnV5emMRPb4V3ZoG3Wsr" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/images/figure-1-2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-8yLnV5emMRPb4V3ZoG3Wsr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-SPcngaoKyDXtdDZMrqQ7w6" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/images/figure-2-3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-SPcngaoKyDXtdDZMrqQ7w6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-ijNuYR3o7bHY9qiCKaZEgp" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/images/figure-2-4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-ijNuYR3o7bHY9qiCKaZEgp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-CUGkJj9wTAzYtiE6mH2nzm" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="ocr/images/figure-3-5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-CUGkJj9wTAzYtiE6mH2nzm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-MR96GCL79P2CJqfeBSn4ui">
#         <div id="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-bTVnYM6WGWSGHMTCdp2tGT" class="ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="ocr/images/figure-4-6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-MR96GCL79P2CJqfeBSn4ui-bTVnYM6WGWSGHMTCdp2tGT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# We can also process tables using the YOLOX model. The tables will be extracted as images.
#
# Use `extract_image_block_types = ["Table"]`
# <div class="alert alert-warning">Running the next cell can take about 16s</div>

# %%
# %%time
image_table_text_elements = partition_pdf(
    filename=filename,
    strategy="hi_res",
    hi_res_model_name="yolox",
    infer_table_structure=True,
    extract_images_in_pdf=True,
    extract_image_block_types=["Image", "Table"],
    extract_image_block_to_payload=False,
    extract_image_block_output_dir=IMG_DIR
)
# Out:
# CPU times: user 1min 48s, sys: 204 ms, total: 1min 49s
# Wall time: 9.29 s

# %% [markdown]
# `unstructured` has a `elements_to_json` function that we can use to convert the table information into a [JSON](https://www.json.org/json-en.html) file.

# %%
from unstructured.staging.base import elements_to_json
tables = [e for e in image_table_text_elements if type(e) == Table]
elements_to_json(image_table_text_elements, filename=f"{filename}.json")
# Out:
# '[\n    {\n        "element_id": "53295da0d27b644623e4293b43a6c852",\n        "metadata": {\n            "coordinates": {\n                "layout_height": 2200,\n                "layout_width": 1700,\n                "points": [\n                    [\n                        1080.2,\n                        -2.9\n                    ],\n                    [\n                        1080.2,\n                        619.8\n                    ],\n                    [\n                        1702.9,\n                        619.8\n                    ],\n                    [\n                        1702.9,\n                        -2.9\n                    ]\n                ],\n                "system": "PixelSpace"\n            },\n            "file_directory": "data",\n            "filename": "grace-blackwell-datasheet.pdf",\n            "filetype": "application/pdf",\n            "image_path": "ocr/images/figure-1-1.jpg",\n            "languages": [\n                "eng"\n            ],\n            "last_modified": "2024-12-16T23:47:19",\n            "page_number": 1\n        },\n        "text": "",\n        "type": "Image"\n    },\n    {\n        "element_id": "79beed28ad345f419b0f8354be01f643",\n        "metadata": {\n            "coordinates": {\n                "layout_height": 2200,\n                "layout_width": 1700,\n                "points": [\n                    [\n                        100.0,\n                        96.3\n                    ],\n                    [\n                        100.0,\n                        126.7\n                    ],\n                    [\n                        236.9,\n                        126.7\n                    ],\n                    [\n                        236.9,\n                        96.3\n                    ]\n                ],\n                "system": "PixelSpace"\n            },\n            "detection_class_prob": 0.43963,\n            "file_directory": "data",\n            "filename": "grace-blackwell-datasheet.pdf",\n            "filetype": "application/pdf",\n            "languages": [\n                "eng"\n            ],\n            "last_modified": "2024-12-16T23:47:19",\n            "page_number": 1\n        },\n        "text": "Datasheet",\n        "type": "Header"\n    },\n    {\n        "element_id": "cc6cba6a759ed4b12217013bf439fa7d",\n        "metadata": {\n            "coordinates": {\n                "layout_height": 2200,\n                "layout_width": 1700,\n                "points": [\n                    [\n                        98.4,\n                        167.8\n                    ],\n                    [\n                        98.4,\n                        227.1\n                    ],\n                    [\n                        368.2,\n                        227.1\n                    ],\n                    [\n                        368.2,\n                        167.8\n                    ]\n                ],\n                "system": "PixelSpace"\n            },\n            "detection_class_prob": 0.42473,\n            "file_directory": "data",\n            "filename": "grace-blackwell-datasheet.pdf",\n            "filetype": "application/pdf",\n            "languages": [\n                "eng"\n            ],\n            "last_modified": "2024-12-16T23:47:19",\n            "page_number": 1,\n            "parent_id": "79beed28ad345f419b0f8354be01f643"\n        },\n        "text": "SI NVIDIA.",\n        "type": "Title"\n    },\n    {\n        "element_id": "c143171f3de02ad8386e5d42888de6f9",\n        "metadata": {\n            "coordinates": {\n                "layout_height": 2200,\n                "layout_width": 1700,\n                "points": [\n                    [\n                        100.0,\n                        319.3\n                    ],\n                    [\n                        100.0,\n                        393.1\n                    ],\n                    [\n  ...

# %% [markdown]
# While the table information was extracted, it's hard to read in this format. We can instead view the table as an image.

# %%
plot_images_from_folder(folder_path=IMG_DIR)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NPC8QWQN6yWDtKsmrSDVqb {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NPC8QWQN6yWDtKsmrSDVqb {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NPC8QWQN6yWDtKsmrSDVqb {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NPC8QWQN6yWDtKsmrSDVqb:checked ~ #ipyplot-html-viewer-textarea-NPC8QWQN6yWDtKsmrSDVqb {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NPC8QWQN6yWDtKsmrSDVqb:checked + #ipyplot-html-viewer-label-NPC8QWQN6yWDtKsmrSDVqb:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-NPC8QWQN6yWDtKsmrSDVqb">
#         <label id="ipyplot-html-viewer-label-NPC8QWQN6yWDtKsmrSDVqb" for="ipyplot-html-viewer-toggle-NPC8QWQN6yWDtKsmrSDVqb">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-NPC8QWQN6yWDtKsmrSDVqb" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ZPjFXnSqUMgsrjCCbn8idu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ZPjFXnSqUMgsrjCCbn8idu">
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-5eipqoZ4pxcekXv7C3cg5h" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/images/figure-4-6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-5eipqoZ4pxcekXv7C3cg5h">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-6y8bGB9gNuZUpCikNHveU2" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/images/table-4-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-6y8bGB9gNuZUpCikNHveU2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-c6MNisjnmaitWWRy9NuxXg" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/images/figure-1-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-c6MNisjnmaitWWRy9NuxXg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-f9HpPsou5vy8J34rpcVYHL" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/images/figure-2-3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-f9HpPsou5vy8J34rpcVYHL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-LCmx96UjWdMEEPuRmda2Jz" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="ocr/images/figure-3-5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-LCmx96UjWdMEEPuRmda2Jz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-C4BAur6iFdy4UTwBqv9mGv" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="ocr/images/figure-2-4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-C4BAur6iFdy4UTwBqv9mGv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-WV2trrx5azMTeWSTw338xK" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="ocr/images/figure-1-2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-WV2trrx5azMTeWSTw338xK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-ZPjFXnSqUMgsrjCCbn8idu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ZPjFXnSqUMgsrjCCbn8idu">
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-5eipqoZ4pxcekXv7C3cg5h" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/images/figure-4-6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-5eipqoZ4pxcekXv7C3cg5h">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-6y8bGB9gNuZUpCikNHveU2" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/images/table-4-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-6y8bGB9gNuZUpCikNHveU2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-c6MNisjnmaitWWRy9NuxXg" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/images/figure-1-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-c6MNisjnmaitWWRy9NuxXg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-f9HpPsou5vy8J34rpcVYHL" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/images/figure-2-3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-f9HpPsou5vy8J34rpcVYHL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-LCmx96UjWdMEEPuRmda2Jz" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="ocr/images/figure-3-5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-LCmx96UjWdMEEPuRmda2Jz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-C4BAur6iFdy4UTwBqv9mGv" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="ocr/images/figure-2-4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-C4BAur6iFdy4UTwBqv9mGv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZPjFXnSqUMgsrjCCbn8idu">
#         <div id="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-WV2trrx5azMTeWSTw338xK" class="ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="ocr/images/figure-1-2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZPjFXnSqUMgsrjCCbn8idu-WV2trrx5azMTeWSTw338xK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## 3.5 Identifying Page Elements with NV-YOLOX
#
# YOLOX-L is a version of YOLOX fine-tuned on 26,000 images from the Digital Corpora dataset, with annotations from Azure AI Document Intelligence. The model is trained to detect **tables**, **charts** and **titles** in documents. A chart is defined as a bar chart, line chart, or pie chart. Titles can be page titles, section titles, or table/chart titles.
#
# Let's use the [nvidia/nv-yolox-page-elements-v1](https://build.nvidia.com/nvidia/nv-yolox-page-elements-v1) model to locate the bounding boxes of elements in a [PNG](https://en.wikipedia.org/wiki/PNG) file. The bounding box tells us the location of an element within an image. Let's use the below image as an example.

# %%
image_filename = "images/nvidia-tensorrt-llm-enhancements-deliver-massive-large-language-model-speedups-on-nvidia-h200.png"
IPyImage(filename=image_filename, width=600)

# %% [markdown]
# We can create a function that calls the YOLOX model API endpoint and returns the page elements with their precise locations on the page.

# %%
def run_yolox(filename):
    invoke_url = "http://ngc-client:9505/v1/cv/nvidia/nv-yolox-page-elements-v1"
    with open(filename, "rb") as f:
        image_b64 = base64.b64encode(f.read()).decode()
    assert len(image_b64) < 250_000, "To upload larger images, use the assets API (see docs)"

    headers = {
       "Authorization": "Bearer $API_KEY_REQUIRED_IF_EXECUTING_OUTSIDE_NGC",
       "Accept": "application/json"
    }

    payload = {
      "input": [
        {
          "type": "image_url",
          "url": f"data:image/png;base64,{image_b64}"
        }
      ]
    }

    response = requests.post(invoke_url, headers=headers, json=payload)
    print(response)
    bounding_boxes = response.json()['data'][0]['bounding_boxes']
    return bounding_boxes

# %% [markdown]
# Time to test it out. Let's use `run_yolox` on the image.

# %%
bounding_boxes = run_yolox(image_filename)
# Out:
# <Response [200]>

# %%
bounding_boxes
# Out:
# {'table': [{'x_min': 0.0267,
#    'y_min': 0.6685,
#    'x_max': 0.9557,
#    'y_max': 0.8435,
#    'confidence': 0.8835}],
#  'chart': [{'x_min': 0.1439,
#    'y_min': 0.2859,
#    'x_max': 0.8052,
#    'y_max': 0.6096,
#    'confidence': 0.9387}],
#  'title': [{'x_min': 0.0266,
#    'y_min': 0.0102,
#    'x_max': 0.8908,
#    'y_max': 0.0549,
#    'confidence': 0.8617}]}

# %% [markdown]
# Here, we can see the model identified 3 elements: a table, a chart, and a title.
#
# Let's visualize those bounding boxes around the elements that were identified by the model:

# %%
# plotting function
def plot_bounding_boxes(image, bounding_boxes):
    annotated_image = image.copy()
    height, width = image.shape[:2]
    color = (128, 128, 128)
    labels = ['table', 'chart', 'title']
    for l in labels:
        # check if label is identified
        if l not in bounding_boxes:
            continue
        T = bounding_boxes[l]
        for t in T:
            x_min = int(width * t['x_min'])
            y_min = int(height * t['y_min'])
            x_max = int(width * t['x_max'])
            y_max = int(height * t['y_max'])
            label = f"{l} {t['confidence']:.2f}"
            color = (0, 255, 0)  # Green color for the box
            cv2.rectangle(annotated_image, (x_min, y_min), (x_max, y_max), color, 2, cv2.LINE_AA)
            cv2.putText(annotated_image, label, (x_min, y_min - 10), cv2.FONT_HERSHEY_PLAIN, fontScale=1.5, color=color, thickness=1)
    return annotated_image

# %% [markdown]
# We can draw the extracted bounding boxes and save them on a temporary image.

# %%
image = cv2.imread(image_filename)
annotated_image = plot_bounding_boxes(image, bounding_boxes)
OUTPUT_IMAGE_PATH = "ocr/outputs/yolox"

# %%
cv2.imwrite(OUTPUT_IMAGE_PATH + '/test_annotated.jpg', annotated_image)
# Out:
# True

# %% [markdown]
# Then, we can visualize the elements detected by `nv-yolox-page-elements-v1`:

# %%
IPyImage(filename=OUTPUT_IMAGE_PATH + '/test_annotated.jpg', width=600)

# %% [markdown]
# ## 3.5.1 Exercise: Bounding Boxes
#
# Now let's try this with our original example NVIDIA GB200 NVL72 white paper from earlier.
#
# First we need to convert each page of the PDF to an image. There are a couple ways to do this. We could process the entire PDF in one go by using `convert_from_path`, which loads all pages into memory at once:
#
# ```
# from pdf2image import convert_from_path
#
# pages = convert_from_path(filename, 500)
# for count, page in enumerate(pages):
#     page.save(f'pdf2image/out_{count}.jpg', 'JPEG')
# ```
#
# However, this can consume significant memory, particularly for large PDFs and systems with limited RAM.
#
# Instead, we can process the data using batching so that only a portion of the PDF is loaded into memory at a time. The `CHUNK_SIZE` can be adjusted based on available system resources to make processing more manageable.

# %%
from pdf2image import pdfinfo_from_path, convert_from_path

filename = "data/grace-blackwell-datasheet.pdf"
PATH_PDF2IMAGE = "ocr/outputs/pdf2image"

CHUNK_SIZE = 20  # depends on RAM
MAX_PAGES = pdfinfo_from_path(filename)["Pages"]

pages = []
for page in range(1, MAX_PAGES, CHUNK_SIZE):
    pages += convert_from_path(filename, first_page=page, last_page=page + CHUNK_SIZE - 1, dpi=100)

for count, page in enumerate(pages):
    page.save(f'{PATH_PDF2IMAGE}/test_{count}.jpg', 'JPEG')

# %% [markdown]
# Let's verify the image chunks were created:

# %%
# !ls $PATH_PDF2IMAGE
# Out:
# test_0.jpg  test_1.jpg	test_2.jpg  test_3.jpg

# %% [markdown]
# Then, let's visualize the created chunks.

# %%
# Now let's visualize the pages
plot_images_from_folder(folder_path=PATH_PDF2IMAGE)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HpyXqptA8D3njNqRdWVAVy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HpyXqptA8D3njNqRdWVAVy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HpyXqptA8D3njNqRdWVAVy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HpyXqptA8D3njNqRdWVAVy:checked ~ #ipyplot-html-viewer-textarea-HpyXqptA8D3njNqRdWVAVy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HpyXqptA8D3njNqRdWVAVy:checked + #ipyplot-html-viewer-label-HpyXqptA8D3njNqRdWVAVy:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-HpyXqptA8D3njNqRdWVAVy">
#         <label id="ipyplot-html-viewer-label-HpyXqptA8D3njNqRdWVAVy" for="ipyplot-html-viewer-toggle-HpyXqptA8D3njNqRdWVAVy">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-HpyXqptA8D3njNqRdWVAVy" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-EJN7oZrwBfvKWrZvDXXyQQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EJN7oZrwBfvKWrZvDXXyQQ">
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-fBTAQApFv3nYLyfmDpCQd2" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/outputs/pdf2image/test_2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-fBTAQApFv3nYLyfmDpCQd2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-CJhfLXv7d4jWjzexYzH3sc" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/outputs/pdf2image/test_0.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-CJhfLXv7d4jWjzexYzH3sc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-PPGDNR453upsyXJPdctMdJ" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/outputs/pdf2image/test_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-PPGDNR453upsyXJPdctMdJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-W7RD3PUtwq9AnuKQY3AeFs" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/outputs/pdf2image/test_3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-W7RD3PUtwq9AnuKQY3AeFs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-EJN7oZrwBfvKWrZvDXXyQQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EJN7oZrwBfvKWrZvDXXyQQ">
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-fBTAQApFv3nYLyfmDpCQd2" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/outputs/pdf2image/test_2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-fBTAQApFv3nYLyfmDpCQd2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-CJhfLXv7d4jWjzexYzH3sc" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/outputs/pdf2image/test_0.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-CJhfLXv7d4jWjzexYzH3sc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-PPGDNR453upsyXJPdctMdJ" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/outputs/pdf2image/test_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-PPGDNR453upsyXJPdctMdJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EJN7oZrwBfvKWrZvDXXyQQ">
#         <div id="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-W7RD3PUtwq9AnuKQY3AeFs" class="ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/outputs/pdf2image/test_3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EJN7oZrwBfvKWrZvDXXyQQ-W7RD3PUtwq9AnuKQY3AeFs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# We can take one of these pages and compute the bounding boxes of the page elements.

# %%
bounding_boxes = run_yolox(PATH_PDF2IMAGE + "/test_2.jpg")
image = cv2.imread(PATH_PDF2IMAGE + "/test_2.jpg")
annotated_image = plot_bounding_boxes(image, bounding_boxes)
cv2.imwrite(OUTPUT_IMAGE_PATH + '/annotated_test_1.jpg', annotated_image)
# Out:
# <Response [200]>
# True

# %% [markdown]
# And we can visualize the identified titles and chart:

# %%
IPyImage(filename=OUTPUT_IMAGE_PATH + '/annotated_test_1.jpg', width=600)

# %% [markdown]
# If you encounter any issues, refer to the prepared folder `TMP_PATH_PDF2IMAGE` by running the next cell.

# %% [markdown]
# ## 3.6 End-to-End Multimodal Data Extraction
#
# Now we've looked at several different methods for pre-processing multimodal PDFs, we can try another end-to-end example.
#
# Here we have a technical paper [ChipNemo](https://arxiv.org/pdf/2311.00176):

# %%
IFrame("ocr/pdfs/ChipNeMo.pdf", width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="ocr/pdfs/ChipNeMo.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The PDF contains a mixture of text under different sections, figures, tables, and graphs.
#
# If we have a folder of PDFs, we will need to define a method to process each one. We can process the PDFs with different chunking strategies using [partition_pdf](https://docs.unstructured.io/api-reference/partition/partitioning).

# %%
class ExtractionPipeline:
    def __init__(self, folder_path):
        self.folder_path = folder_path
        self.pdf_filenames = self.get_pdf_filenames_from_folder()

    def get_pdf_filenames_from_folder(self):
        return list(Path(self.folder_path).glob("*.pdf"))

    def load_and_split_documents(self):
        for pdf_filename in self.pdf_filenames:
            print("processing document: ", pdf_filename)
            raw_pdf_elements = partition_pdf(
                pdf_filename,
                infer_table_structure=True,
                strategy='hi_res'
            )
            Text_elements = [Document(page_content=e.text.strip(), metadata={"filename": e.metadata.filename, "source_type": "text"}) for e in raw_pdf_elements if type(e) == Text or CompositeElement]
            print("Number of Detected Text elements: ", len(Text_elements))

            # Tables
            Table_elements = [Document(page_content=e.metadata.text_as_html, metadata={"filename": e.metadata.filename, "source_type": "table_html"}) for e in raw_pdf_elements if type(e) == Table]
            print("Number of Detected HTML Tables: ", len(Table_elements))
        return Text_elements, Table_elements

# %% [markdown]
# Let's now call the extraction function. This will extract text and tables (in HTML format) from the PDFs in the folder using the `by_title` strategy. We've specified parameters such as `max_characters`, `new_after_n_chars`, and `combine_text_under_n_chars` to control the chunk sizes of the text elements.

# %%
PDF_FOLDER_PATH = "ocr/pdfs"
Extraction_pipeline = ExtractionPipeline(folder_path=PDF_FOLDER_PATH)

# %% [markdown]
# <div class="alert alert-warning">Running the next cell can take about 3mn.</div>

# %%
# %%time
# 2min 42s if you use default, 2s if you use fast but you get only text (no tabular data)
Text_elements, Table_elements = Extraction_pipeline.load_and_split_documents()
# Out:
# processing document:  ocr/pdfs/ChipNeMo.pdf
# Number of Detected Text elements:  465
# Number of Detected HTML Tables:  17
# CPU times: user 6min 50s, sys: 941 ms, total: 6min 51s
# Wall time: 1min 21s

# %% [markdown]
# Let's verify the results:

# %%
Text_elements[0].page_content, Text_elements[0].metadata
# Out:
# ('4', {'filename': 'ChipNeMo.pdf', 'source_type': 'text'})

# %%
Table_elements[0].page_content, Table_elements[0].metadata
# Out:
# ('<table><thead><tr><th>Model Size</th><th>Pretraining</th><th>| DAPT</th><th>| SFT</th></tr></thead><tbody><tr><td>7B</td><td>184,320</td><td>2,620</td><td>90</td></tr><tr><td>13B</td><td>368,640</td><td>4,940</td><td>160</td></tr><tr><td>70B</td><td>1,720,320 |</td><td>20,500</td><td>| 840</td></tr></tbody></table>',
#  {'filename': 'ChipNeMo.pdf', 'source_type': 'table_html'})

# %% [markdown]
# Finally, we can [pickle](https://docs.python.org/3/library/pickle.html) our extracted data to be stored in our hypothetical RAG database.

# %%
# save text and HTML tables
import pickle

PATH_DATA = "ocr/outputs/data_dir_extracted"

with open(PATH_DATA + '/tables_db.pkl', 'wb') as fp:
    pickle.dump(Table_elements, fp)

with open(PATH_DATA + '/text_db.pkl', 'wb') as fp:
    pickle.dump(Text_elements, fp)

# %% [markdown]
# After saving all the text and table information from the paper, we can look at the `high_res` chunking strategy for comparison.

# %%
class VisualExtractionPipeline:
    def __init__(self, folder_path):
        self.folder_path = folder_path
        self.pdf_filenames = self.get_pdf_filenames_from_folder()

    def get_pdf_filenames_from_folder(self):
        return list(Path(self.folder_path).glob("*.pdf"))

    def load_and_split_documents(self):
        for pdf_filename in self.pdf_filenames:
            print("processing document: ", pdf_filename)
            image_text_elements = partition_pdf(
                filename=pdf_filename,
                strategy="hi_res",
                hi_res_model_name="yolox",
                extract_images_in_pdf=True,
                extract_image_block_types=["Image"],
                extract_image_block_to_payload=False,
                extract_image_block_output_dir="ocr/figures"
            )
        image_elements = [Document(page_content=e.metadata.image_path, metadata={"filename": e.metadata.filename, "source_type": "image"}) for e in image_text_elements if type(e) == Image]
        #table_elements = [Document(page_content=e.metadata.image_path, metadata={"filename": e.metadata.filename, "source_type": "image_table"}) for e in image_text_elements if type(e) == Table]
        return image_elements  # + table_elements

# %% [markdown]
# <div class="alert alert-warning">Running the next cell can take about 2-3mn.</div>

# %%
# %%time
Extraction_pipeline_visual = VisualExtractionPipeline(folder_path=PDF_FOLDER_PATH)
image_elements = Extraction_pipeline_visual.load_and_split_documents()
# Out:
# processing document:  ocr/pdfs/ChipNeMo.pdf
# CPU times: user 6min 52s, sys: 945 ms, total: 6min 53s
# Wall time: 1min 18s

# %% [markdown]
# Finally, let's see the images we have extracted from the PDF:

# %%
images = [e.page_content for e in image_elements]
plot_images_from_folder(image_files=images)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TGiyEm7Tib4urriNZSzRZb {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TGiyEm7Tib4urriNZSzRZb {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TGiyEm7Tib4urriNZSzRZb {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TGiyEm7Tib4urriNZSzRZb:checked ~ #ipyplot-html-viewer-textarea-TGiyEm7Tib4urriNZSzRZb {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TGiyEm7Tib4urriNZSzRZb:checked + #ipyplot-html-viewer-label-TGiyEm7Tib4urriNZSzRZb:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TGiyEm7Tib4urriNZSzRZb">
#         <label id="ipyplot-html-viewer-label-TGiyEm7Tib4urriNZSzRZb" for="ipyplot-html-viewer-toggle-TGiyEm7Tib4urriNZSzRZb">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TGiyEm7Tib4urriNZSzRZb" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bMeSWfgmLNdk8jsTNm2eGE {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bMeSWfgmLNdk8jsTNm2eGE">
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-33cEHiHKMx86XxRYbDsD4j" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/figures/figure-2-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-33cEHiHKMx86XxRYbDsD4j">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-Py4HcNsFgW5kEYefN4pgSr" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/figures/figure-3-2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-Py4HcNsFgW5kEYefN4pgSr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-EjY3rfJ6X6nQqPs5GcuEQv" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/figures/figure-4-3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-EjY3rfJ6X6nQqPs5GcuEQv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-3dTXkvc2QA6hPFAm8kvgSQ" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/figures/figure-5-4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-3dTXkvc2QA6hPFAm8kvgSQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-9J3dKFoFUFNfp4JqcXnHQL" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="ocr/figures/figure-5-5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-9J3dKFoFUFNfp4JqcXnHQL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-bfjeKQw45tett9jketyijB" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="ocr/figures/figure-6-6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-bfjeKQw45tett9jketyijB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-dWNyXdus27bF8WkgLJpMAX" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="ocr/figures/figure-6-7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-dWNyXdus27bF8WkgLJpMAX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-eUujPKgXCpKAWc
#         <style>
#         #ipyplot-imgs-container-div-bMeSWfgmLNdk8jsTNm2eGE {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bMeSWfgmLNdk8jsTNm2eGE">
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-33cEHiHKMx86XxRYbDsD4j" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="ocr/figures/figure-2-1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-33cEHiHKMx86XxRYbDsD4j">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-Py4HcNsFgW5kEYefN4pgSr" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="ocr/figures/figure-3-2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-Py4HcNsFgW5kEYefN4pgSr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-EjY3rfJ6X6nQqPs5GcuEQv" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="ocr/figures/figure-4-3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-EjY3rfJ6X6nQqPs5GcuEQv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-3dTXkvc2QA6hPFAm8kvgSQ" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="ocr/figures/figure-5-4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-3dTXkvc2QA6hPFAm8kvgSQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-9J3dKFoFUFNfp4JqcXnHQL" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="ocr/figures/figure-5-5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-9J3dKFoFUFNfp4JqcXnHQL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-bfjeKQw45tett9jketyijB" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="ocr/figures/figure-6-6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-bfjeKQw45tett9jketyijB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-dWNyXdus27bF8WkgLJpMAX" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="ocr/figures/figure-6-7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-dWNyXdus27bF8WkgLJpMAX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-eUujPKgXCpKAWcMdcveWdS" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="ocr/figures/figure-7-8.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-eUujPKgXCpKAWcMdcveWdS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-XWdhEKRsfHoicqFAHYFv2b" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="ocr/figures/figure-7-9.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-XWdhEKRsfHoicqFAHYFv2b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bMeSWfgmLNdk8jsTNm2eGE">
#         <div id="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-Xq6ksQgCBH24yokQbVyeqR" class="ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="ocr/figures/figure-7-10.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bMeSWfgmLNdk8jsTNm2eGE-Xq6ksQgCBH24yokQbVy

# %% [markdown]
# As before, we can save our data in our hypothetical database.

# %%
# save text and HTML tables
import pickle

PATH_DATA = "ocr/outputs/data_dir_extracted"

with open(PATH_DATA + '/images_db.pkl', 'wb') as fp:
    pickle.dump(image_elements, fp)

# %% [markdown]
# ## Next
# Congrats on making it to the end!
#
# In this notebook, we:
# - Pre-processed multimodal PDFs using the *Unstructured* library, which is the first step for creating a multimodal RAG pipeline, and explored various functions to extract text, tables, images, and charts from PDFs.
# - Explored NIMs components designed for multimodal content extraction to streamline the process.
#
# In the next section of the course, we will use a completed Video Search and Summary (VSS) orchestrated pipeline. Let's learn more about it in the upcoming slide deck.

# %% [markdown]
# <center><a href="https://www.nvidia.com/en-us/training/"><img src="https://dli-lms.s3.amazonaws.com/assets/general/DLI_Header_White.png" width="400" height="186" /></a></center>
