# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('./data/road1.jpg')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
temp_img = img[200:400, 200:400].copy()

plt.imshow(temp_img)

# %%
print(temp_img.shape)
# Out:
# (200, 200, 3)

# %%
len(temp_img[0])
# Out:
# 200

# %%
temp_img[0][0]
# Out:
# array([ 72, 110, 146], dtype=uint8)

# %%
img[200:400, 200:400] = 0
plt.imshow(img)

# %%
img[200:400, 200:400] = temp_img
plt.imshow(img)
