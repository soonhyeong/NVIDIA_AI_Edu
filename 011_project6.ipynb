# %% [markdown]
# <a href="https://colab.research.google.com/github/soonhyeong/NVIDIA_AI_Edu/blob/main/011_project6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 기본 셋업 (맨 처음 한 번 실행)
# !pip install -q koreanize-matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib
plt.rcParams['axes.unicode_minus'] = False
print("준비 완료")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 47.7 MB/s eta 0:00:00
# 준비 완료

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA/과일.csv", encoding = "euc-kr")
df.head()
# Out:
#    과일명  수량     가격      금액
# 0   사과  30   1500   45000
# 1  바나나  50    800   40000
# 2   키위  12   1200   14400
# 3   딸기  70   5000  350000
# 4   수박   6  22000  132000

# %%
# 최댓값 / 최솟값
df = pd.read_csv("/content/drive/MyDrive/DATA/과일.csv", encoding = "euc-kr")

#print(df.max())
#print(df.min())

print("수량 중 최댓값의 찾고 인덱스 반환 :", df["수량"].idxmax())
print("수량 중 최솟값의 찾고 인덱스 반환 :", df["수량"].idxmin())

df.loc[df["수량"].idxmax()] # "수량" 열에서 가장 큰 값을 찾은 후 행으로 반환
df.loc[df["수량"].idxmin()] # "수량" 열에서 가장 낮은 값을 찾은 후 행으로 반환

df.loc[df["가격"].idxmin()] # "가격" 열에서 가장 낮은 값을 찾은 후 행으로 반환
# Out:
# 수량 중 최댓값의 찾고 인덱스 반환 : 3
# 수량 중 최솟값의 찾고 인덱스 반환 : 4
# 과일명      바나나
# 수량        50
# 가격       800
# 금액     40000
# Name: 1, dtype: object

# %%
# 열 이름 변경하기
df = pd.read_csv("/content/drive/MyDrive/DATA/과일.csv", encoding = "euc-kr")

df.columns = ["name", "amount", "price", "total"]
df.columns

df.sort_values(by = "total", ascending = False) # by를 기준으로 True(오름차순), False(내림차순) 정렬
# Out:
#   name  amount  price   total
# 6    귤      60  15000  900000
# 5   포도      20  30000  600000
# 3   딸기      70   5000  350000
# 4   수박       6  22000  132000
# 0   사과      30   1500   45000
# 1  바나나      50    800   40000
# 2   키위      12   1200   14400

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA/seoul.csv", encoding = "euc-kr")

df.columns = ['년월', '평균기온', '최저기온', '최고기온']

res1 = df["평균기온"].idxmax()
#print(df.loc[res1])

res2 = df["최저기온"].idxmin()
#print(df.loc[res2])

res3 = df["최고기온"].idxmax()
#print(df.loc[res3])

years = [str(i) for i in range(2011, 2021)]

df2 = df[df["년월"].str.contains("8월")]
df3 = df[df["년월"].str.contains("3월")]

plt.plot(years,df2["평균기온"])
plt.plot(years,df3["평균기온"])
plt.xticks(rotation=45)
plt.show()
