# %% [markdown]
# <a href="https://colab.research.google.com/github/soonhyeong/NVIDIA_AI_Edu/blob/main/013_project8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 기본 셋업 (맨 처음 한 번 실행)
# !pip install -q koreanize-matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib
plt.rcParams['axes.unicode_minus'] = False
print("준비 완료")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 33.8 MB/s eta 0:00:00
# 준비 완료

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA/penguins.csv", encoding='utf-8')
df
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 0             1     Adelie  Torgersen            39.1           18.7
# 1             2     Adelie  Torgersen            39.5           17.4
# 2             3     Adelie  Torgersen            40.3           18.0
# 3             4     Adelie  Torgersen             NaN            NaN
# 4             5     Adelie  Torgersen            36.7           19.3
# ..          ...        ...        ...             ...            ...
# 339         340  Chinstrap      Dream            55.8           19.8
# 340         341  Chinstrap      Dream            43.5           18.1
# 341         342  Chinstrap      Dream            49.6           18.2
# 342         343  Chinstrap      Dream            50.8           19.0
# 343         344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# ...

# %%
df.columns = ["번호","종", "섬", "부리길이", "부리너비", "날개길이", "체중", "성별","연도"]
df
# Out:
#       번호          종          섬  부리길이  부리너비   날개길이      체중      성별    연도
# 0      1     Adelie  Torgersen  39.1  18.7  181.0  3750.0    male  2007
# 1      2     Adelie  Torgersen  39.5  17.4  186.0  3800.0  female  2007
# 2      3     Adelie  Torgersen  40.3  18.0  195.0  3250.0  female  2007
# 3      4     Adelie  Torgersen   NaN   NaN    NaN     NaN     NaN  2007
# 4      5     Adelie  Torgersen  36.7  19.3  193.0  3450.0  female  2007
# ..   ...        ...        ...   ...   ...    ...     ...     ...   ...
# 339  340  Chinstrap      Dream  55.8  19.8  207.0  4000.0    male  2009
# 340  341  Chinstrap      Dream  43.5  18.1  202.0  3400.0  female  2009
# 341  342  Chinstrap      Dream  49.6  18.2  193.0  3775.0    male  2009
# 342  343  Chinstrap      Dream  50.8  19.0  210.0  4100.0    male  2009
# 343  344  Chinstrap      Dream  50.2  18.7  198.0  3775.0  female  2009
#
# [344 rows x 9 columns]

# %%
df.columns = ["번호","종", "섬", "부리길이", "부리너비", "날개길이", "체중", "성별","연도"]
print(df.isnull())
df.isnull().sum()
# Out:
#         번호      종      섬   부리길이   부리너비   날개길이     체중     성별     연도
# 0    False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False
# 3    False  False  False   True   True   True   True   True  False
# 4    False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 339  False  False  False  False  False  False  False  False  False
# 340  False  False  False  False  False  False  False  False  False
# 341  False  False  False  False  False  False  False  False  False
# 342  False  False  False  False  False  False  False  False  False
# 343  False  False  False  False  False  False  False  False  False
#
# [344 rows x 9 columns]
# 번호       0
# 종        0
# 섬        0
# 부리길이     2
# 부리너비     2
# 날개길이     2
# 체중       2
# 성별      11
# 연도       0
# dtype: int64

# %%
df.columns = ["번호","종", "섬", "부리길이", "부리너비", "날개길이", "체중", "성별","연도"]
print(df["섬"].value_counts())
print(df["성별"].value_counts())
df["종"].value_counts()
# Out:
# 섬
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
# 성별
# male      168
# female    165
# Name: count, dtype: int64
# 종
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df = df[["종", "부리길이", "날개길이", "성별"]]
df
# Out:
#              종  부리길이   날개길이      성별
# 0       Adelie  39.1  181.0    male
# 1       Adelie  39.5  186.0  female
# 2       Adelie  40.3  195.0  female
# 3       Adelie   NaN    NaN     NaN
# 4       Adelie  36.7  193.0  female
# ..         ...   ...    ...     ...
# 339  Chinstrap  55.8  207.0    male
# 340  Chinstrap  43.5  202.0  female
# 341  Chinstrap  49.6  193.0    male
# 342  Chinstrap  50.8  210.0    male
# 343  Chinstrap  50.2  198.0  female
#
# [344 rows x 4 columns]

# %%
sns.scatterplot(x = "부리길이", y = "날개길이", data=df)
plt.show()

# %%
sns.scatterplot(x = "부리길이", y = "날개길이", hue = "종", data=df)

plt.show()

# %%
sns.scatterplot(x = "부리길이", y = "날개길이", hue = "종", style = "성별",s = 50,alpha = 0.8,data=df)

plt.show()
